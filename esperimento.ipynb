# %%
import matplotlib.pyplot as plt
import numpy as np
import popolazione as pop

STORICO, POPOLAZIONE = pop.esperimento(120)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
import virus as vir
VIRUS = vir.Setup(POPOLAZIONE,STORICO,120)
print(np.sum(VIRUS > 1000))
plt.imshow(VIRUS, cmap='hot')
plt.colorbar()
plt.title('Heatmap VIRUS (< 1000)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 import virus as vir
# ----> 2 VIRUS = vir.Setup(POPOLAZIONE,STORICO,120)
#       3 print(np.sum(VIRUS > 1000))
#       4 plt.imshow(VIRUS, cmap='hot')
#
# File c:\Users\Loryb\Metodi-Computazionali\Metodi-Computazionali\progetto\virus.py:51, in Setup(POPOLAZIONE, STORICO, giorno)
#      48 X_i   = Xi(VIRUS, VIRUS_MASK)
#      50 N     = Vp * X_i * STORICO[i]
# ---> 51 if(N > 1000):
#      52     N = 0
#      54 VIRUS = VIRUS + N
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
