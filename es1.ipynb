# %%
import matplotlib.pyplot as plt
import numpy as np
import random as ran
from time import time

Nlim = 1000

def STATS(ARR,N):
    try:
        MAX = max(ARR)
        MIN = min(ARR)
        AVG = sum(ARR)/N
        DVSTD = (sum(ARR**2)-N*AVG**2)/(N-1)  
    except ValueError:
        MAX=MIN=AVG=DVSTD=0

    return (MAX,MIN,AVG,DVSTD)
    

DATA_MAX = np.zeros(Nlim)
DATA_MIN = np.zeros(Nlim)
DATA_AVG = np.zeros(Nlim)
DATA_DVSTD = np.zeros(Nlim)
for i in range(Nlim):
    A = np.zeros(i)

    for j in range(i):
        A[j] = ran.random()

    DATA_MAX[i],DATA_MIN[i],DATA_AVG[i],DATA_DVSTD[i] = STATS(A,i)
# Out:
# C:\Users\famig\AppData\Local\Temp\ipykernel_17564\468429945.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   DVSTD = (sum(ARR**2)-N*AVG**2)/(N-1)

# %%
X = np.linspace(0,1,Nlim)

plt.plot(X,DATA_AVG)
plt.axhline(y=0.5, linestyle='--', color='black')
plt.show()

plt.plot(X,DATA_DVSTD)
plt.axhline(y=1/12, linestyle='--', color='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random as ran
from time import time

Nlim = 1000

def STATS(ARR,N):
    try:
        MAX = max(ARR)
        MIN = min(ARR)
        AVG = sum(ARR)/N
        DVSTD = (sum(ARR**2)-N*AVG**2)/(N-1)  
    except ValueError:
        MAX=MIN=AVG=DVSTD=0

    return (MAX,MIN,AVG,DVSTD)
    

DATA_MAX = np.zeros(Nlim)
DATA_MIN = np.zeros(Nlim)
DATA_AVG = np.zeros(Nlim)
DATA_DVSTD = np.zeros(Nlim)
for i in range(Nlim):
    A = np.random.normal(0,0.1,i)

    DATA_MAX[i],DATA_MIN[i],DATA_AVG[i],DATA_DVSTD[i] = STATS(A,i)
# Out:
# C:\Users\famig\AppData\Local\Temp\ipykernel_17564\2053160199.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   DVSTD = (sum(ARR**2)-N*AVG**2)/(N-1)

# %%
X = np.linspace(0,1,Nlim)

plt.plot(X,DATA_AVG)
plt.axhline(y=0, linestyle='--', color='black')
plt.show()

plt.plot(X,DATA_DVSTD)
plt.axhline(y=0.01, linestyle='--', color='black')
plt.show()
