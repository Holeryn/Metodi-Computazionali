# %%
import matplotlib.pyplot as plt
import numpy as np
import popolazione as pop
POPOLAZIONE = pop.esperimento(1)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
POPOLAZIONE = pop.esperimento(52)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
POPOLAZIONE = pop.esperimento(200)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
plt.imshow(POPOLAZIONE[0]**2, cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import popolazione as pop
POPOLAZIONE = pop.esperimento(175)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import popolazione as pop
POPOLAZIONE = pop.esperimento(210)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()
