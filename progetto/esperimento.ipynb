# %%
import popolazione as pop
pop.esperimento(15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import popolazione as pop
# ----> 2 pop.esperimento(15)
#
# File c:\Users\famig\Metodi-Computazionali\progetto\popolazione.py:59, in esperimento(giorni)
#      56 POPOLAZIONE[0][:][:] = 1
#      58 for g in range(giorni):
# ---> 59     for i in W:
#      60         for j in H:
#      61             U = G(i,j,g)
#
# TypeError: 'int' object is not iterable
