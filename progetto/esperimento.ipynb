# %%
import matplotlib.pyplot as plt
import numpy as np
import popolazione as pop

STORICO, POPOLAZIONE = pop.esperimento(60)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
import virus as vir
VIRUS = vir.Setup(POPOLAZIONE,STORICO,60)
plt.imshow(VIRUS, cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()
