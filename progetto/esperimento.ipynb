# %%
import matplotlib.pyplot as plt
import numpy as np
import popolazione as pop

STORICO, POPOLAZIONE = pop.esperimento(120)
plt.imshow(POPOLAZIONE[0], cmap='hot')
plt.colorbar()
plt.title('Heatmap Popolazione')
plt.show()

# %%
import virus as vir
import importlib 
importlib.reload(vir)

N,VIRUS_LAYERS = vir.setup_virus(120,STORICO)


import virus as vir
import importlib 
importlib.reload(vir)

N,VIRUS_LAYERS = vir.setup_virus(120,STORICO)

# Visualizza l'ultimo giorno
plt.imshow(VIRUS_LAYERS[-1], cmap='hot')
plt.colorbar()
plt.title('Heatmap VIRUS ultimo giorno')
plt.show()

X = np.linspace(0,120,120)
Y = vir.P(X)*0.341*(np.sum(N[-39:-32]))/7
plt.plot(X,Y)
